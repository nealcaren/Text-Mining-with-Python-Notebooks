# %% [markdown]
# ## Install the required packages

# %%
# %conda install -c conda-forge pdf2image tesseract
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/nealcaren/anaconda3/envs/standard
#
#   added / updated specs:
#     - pdf2image
#     - tesseract
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     pdf2image-1.13.1           |             py_0          12 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          12 KB
#
# The following NEW packages will be INSTALLED:
#
#   leptonica          conda-forge/osx-64::leptonica-1.76.0-h1ccaaf6_4
#   libwebp            conda-forge/osx-64::libwebp-0.5.2-7
#   tesseract          conda-forge/osx-64::tesseract-3.05.02-h1ccaaf6_0
#
# The following packages will be UPDATED:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge::ca-certificates-2020.4.5.1-hecc5488_0
# ...

# %%
# %pip install pyocr
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pdf2image import convert_from_path

from pyocr.tesseract import image_to_string
from pyocr.builders import TextBuilder

# %%
fn = '/Users/nealcaren/Downloads/sw_1913_!.pdf'

# %%
pages = convert_from_path(fn)

# %%
import pdf2image

# %%
pages = convert_from_path('https://www.marxists.org/history/usa/pubs/socialist-woman/101100-progressivewoman-v4w42.pdf')

# %%
article[5]
# Out:
# <PIL.PpmImagePlugin.PpmImageFile image mode=RGB size=1647x2351 at 0x11F89F9D0>

# %%
text = image_to_string(article[5])

# %%
print(text)
# Out:
# THE PROGRESSIVE WOMAN.
#
#
#
# Women and :i‘he Loan Association
#
# Did you ever have any dealing with a
# loan association? No? Then if you are a
# working man or woman, be thankful that you
# have had sufficient employment to keep out
# of the clutches of the loan sharks.
#
# .-\ loan association is formed primarily for
# the purpose of making loans upon the turni-
# ture of those unfortuuales who are compelled,
# generally speaking, by (lire necessity to resort
# to this method of obtaining food for them-
# selves or family. The loan association is
# allowed by law (in the state of New York)
# to charge 2 per cent per month, 24 per cent
# per annum, think of it! For every $100 loaned
# they collect $24, payable monthly. How long
# before the interest paid will amount to more
# than the original loan which remains unpaid?
#
# In addition the borrower must pay $1 ap-
# plication fee for examination of property and
# $t for drawing and ﬁling necessary papers
# ...

# %%
pages = convert_from_path(fn)

contents = []
for n, page in enumerate(pages):
    meta = {'text' : image_to_string(page),
           'page'  : n + 1,
           'fn' :    fn}
    
    contents.append(meta)

# %%
import pandas as pd
print(pd.DataFrame(texts)['text'].values[5])
# Out:
# THAT WASHINGTON STATE CAMPAIGN
#
# By ANNA A. MALEY
#
# Recent Socialist Candidate for Governor in Washington
#
#
#
# FFICIAL figures issued from the office of
# the Secretary of State give the total vote
# of Washington as 331,790, the presiden-
#
# tial candidates polling as follows: E. V. Debs,
# 40,445; Theodore Roosevelt, 113,698; Wood-
# row Wilson, 86,840; William H. Taft, 70,445.
#
# Among the Socialist state nominees, Horace
# G. Cupples, standing for land commissioner,
# received the highest vote, 46,872. The lowest
# Socialist vote, 37,155, was cast for the writer,
# who had been nominated for the office of gov-
# ernor.
#
# Other state nominees received as follows:
# J. E. Arnett, for state auditor, 40,683; Mrs.
# Minnie Parks, for state treasurer, 40,668;
# Frances C. Sylvester, state superintendent, 40,-
# 061; Frans Bostrom, secretary of state, 39,595 ;
# Adam H. Barth, lieutenant governor, 38,655.
#
# The sin of the gubernatorial nominee, in
# ...
